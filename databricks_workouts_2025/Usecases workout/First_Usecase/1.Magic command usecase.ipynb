# %% [markdown]
# #Magic Commend workout
# Think of this a learing zone where you can try magic commands from basics to advanced level <br>\
# HI Team. Myself <span style="color:blue; font-weight:bold;">SENTHUR KUMARAN</span> ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql

CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics

# %%
# %run
"/Users/senthurkumaran03@gmail.com/databricks_code_repo/databricks_workouts_2025/Usecases workout/Dummy/"

# %%
# %fs
ls /Workspace

# %%
# %python
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",header=True).show(2)

# %%
#df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
#df1.write.saveAsTable("default.mobile_os_usage_tbl")

df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
df1.write.saveAsTable("default.Sampdata_TB4")
display(df1)

# %%
# %sql
select * from default.Sampdata_TB4;

# %%
# %python
Name='Senthur Kumaran'
print(Name.upper())

# %%
# %pip install pypi

# %%
# %python

import pandas as pd

file_path = "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

pd.read_csv(file_path).head()

# %%
# %sh
echo "Magic commands tasks completed"
