# %%
# %run /Workspace/Users/senthurkumaran03@gmail.com/databricks_code_repo/databricks_workouts_2025/Usecases_workout/generic_functions_nb1

# %%
# %run /Workspace/Users/senthurkumaran03@gmail.com/databricks_code_repo/databricks_workouts_2025/Usecases_workout/business_specific_generic_function_fw_nb

# %%
#spark=return_sparksession("logistics project")
bronze_df1=return_df(spark,"/Volumes/workspace/logistics/volume1/datalaketarget/bronzetarget1",'delta')
bronze_df1.show(2)

# %%
silver_df1=staff_data_standardization(bronze_df1)

# %%
write_df(silver_df1,"silver_staff_tbl1",'tbl')
spark.read.table("silver_staff_tbl1").show(10)
