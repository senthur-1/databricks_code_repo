# %%
dbutils.widgets.text("catalog","")
CATALOG=dbutils.widgets.get("catalog")
dbutils.widgets.text("schema","")
SCHEMA=dbutils.widgets.get("schema")
print(CATALOG)
print(SCHEMA)

# %%
#Benfit: pass parameters
#Drawback: We can't run the notebook inline/locally, so we can't take the output of the child notebook directly
child_nb_output=dbutils.notebook.run("/Workspace/Users/senthurkumaran03@gmail.com/databricks_code_repo/databricks_workouts_2025/Usecases_workout/generic_project/magic_run_vs_notebook_run_learning/child1_nb_config",60,{"catalog":CATALOG,"schema":SCHEMA})
print(child_nb_output)

# %% [markdown]
# #####Drawback: Can't pass parameters
# ######Benifi: We can run the child notebook inline/locally, so we can take the output of the child notebook directly

# %%
# %run /Workspace/Users/senthurkumaran03@gmail.com/databricks_code_repo/databricks_workouts_2025/Usecases_workout/generic_project/magic_run_vs_notebook_run_learning/child1_nb_config

# %%
# %run ./child2_nb_generic_function

# %%
print(SRC1)
print(TGT1)

# %%
print(fun1(100))
